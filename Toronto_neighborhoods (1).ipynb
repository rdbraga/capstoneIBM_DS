# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

#!conda install -c anaconda beautifulsoup4

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Import Toronto Postal Codes data and copy to dataframe

# %%
from bs4 import BeautifulSoup
import requests
r  = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
data = r.text
soup = BeautifulSoup(data)

table = soup.find( "table", {"class":"wikitable sortable"} )

rows=list()
for row in table.findAll("tr"):
   rows.append(row)

l = []
for tr in rows:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    l.append(row)
toronto_df = pd.DataFrame(l, columns=['PostalCode','Borough','Neighborhood'])

# %% [markdown]
# #### Clean data

# %%
toronto_df = toronto_df.replace(to_replace='none', value=np.nan).dropna()
toronto_df = toronto_df[toronto_df['Borough'] != 'Not assigned']
toronto_df.reset_index(drop=True)
toronto_df['Neighborhood'] = toronto_df['Neighborhood'].str[:-1]

# %%
toronto_df.groupby('PostalCode').agg(dict(Borough = 'min', Neighborhood = lambda y: '%s'%', '.join(y)))
                             #   .agg(dict(A = 'sum', B = 'sum', C = lambda x: '{%s}'%', '.join(x)))
toronto_df.loc[toronto_df['Neighborhood'].str.contains("Not assign"), 'Neighborhood'] = toronto_df['Borough']

# %%
toronto_df[toronto_df['Borough'] == 'Queen\'s Park']
toronto_df.shape
# Out:
# (211, 3)

# %% [markdown]
# #### Get geolocation data and merge with PostalCodes data

# %%
pc  = requests.get("http://cocl.us/Geospatial_data")
data_pc = pc.text
soup_pc = BeautifulSoup(data_pc)
postalCodes = soup_pc.find('p').getText()

# %%
postalCodes.splitlines()
postalCodes_df = pd.DataFrame(postalCodes.splitlines())
postalCodes_df = pd.DataFrame(postalCodes_df[0].str.split(',').tolist(),
                                   columns = ['PostalCode','Latitude','Longitude'])
postalCodes_df = postalCodes_df[postalCodes_df['PostalCode'] != 'Postal Code']
toronto_data = pd.merge(toronto_df, postalCodes_df, left_on='PostalCode', right_on='PostalCode', how='left')
toronto_data = toronto_data[toronto_data['Borough'].str.contains('Toronto')]
toronto_data
# Out:
#     PostalCode           Borough  \
# 2          M5A  Downtown Toronto
# 3          M5A  Downtown Toronto
# 13         M5B  Downtown Toronto
# 14         M5B  Downtown Toronto
# 27         M5C  Downtown Toronto
# 36         M4E      East Toronto
# 37         M5E  Downtown Toronto
# 41         M5G  Downtown Toronto
# 42         M6G  Downtown Toronto
# 49         M5H  Downtown Toronto
# 50         M5H  Downtown Toronto
# 51         M5H  Downtown Toronto
# 52         M6H      West Toronto
# 53         M6H      West Toronto
# 61         M5J  Downtown Toronto
# 62         M5J  Downtown Toronto
# 63         M5J  Downtown Toronto
# 64         M6J      West Toronto
# 65         M6J      West Toronto
# 72         M4K      East Toronto
# 73         M4K      East Toronto
# 74         M5K  Downtown Toronto
# 75         M5K  Downtown Toronto
# 76         M6K      West Toronto
# 77         M6K      West Toronto
# 78         M6K      West Toronto
# 85         M4L      East Toronto
# 86         M4L      East Toronto
# 87         M5L  Downtown Toronto
# 88         M5L  Downtown Toronto
# 99         M4M      East Toronto
# 112        M4N   Central Toronto
# 113        M5N   Central Toronto
# 121        M4P   Central Toronto
# 122        M5P   Central Toronto
# 123        M5P   Central Toronto
# 124        M6P      West Toronto
# 125        M6P      West Toronto
# 130        M4R   Central Toronto
# 131        M5R   Central Toronto
# 132        M5R   Central Toronto
# 133        M5R   Central Toronto
# 134        M6R      West Toronto
# 135        M6R      West Toronto
# 142        M4S   Central Toronto
# 143        M5S  Downtown Toronto
# 144        M5S  Downtown Toronto
# 145        M6S      West Toronto
# 146        M6S      West Toronto
# 150        M4T   Central Toronto
# 151        M4T   Central Toronto
# 152        M5T  Downtown Toronto
# 153        M5T  Downtown Toronto
# 154        M5T  Downtown Toronto
# 159        M4V   Central Toronto
# 160        M4V   Central Toronto
# 161        M4V   Central Toronto
# 162        M4V   Central Toronto
# 163        M4V   Central Toronto
# 164        M5V  Downtown Toronto
# 165        M5V  Downtown Toronto
# 166        M5V  Downtown Toronto
# 167        M5V  Downtown Toronto
# 168        M5V  Downtown Toronto
# 169        M5V  Downtown Toronto
# 170        M5V  Downtown Toronto
# 183        M4W  Downtown Toronto
# 184        M5W  Downtown Toronto
# 189        M4X  Downtown Toronto
# 190        M4X  Downtown Toronto
# 191        M5X  Downtown Toronto
# 192        M5X  Downtown Toronto
# 196        M4Y  Downtown Toronto
# 197        M7Y      East Toronto
#
#                                           Neighborhood    Latitude  \
# 2                                         Harbourfront  43.6542599
# 3                                          Regent Park  43.6542599
# 13                                             Ryerson  43.6571618
# 14                                     Garden District  43.6571618
# 27                                      St. James Town  43.6514939
# 36                                         The Beaches  43.6763574
# 37                                         Berczy Park  43.6447708
# 41                                  Central Bay Street  43.6579524
# 42                                            Christie   43.669542
# 49                                            Adelaide  43.6505712
# 50                                                King  43.6505712
# 51                                            Richmond  43.6505712
# 52                                  Dovercourt Village  43.6690051
# 53                                            Dufferin  43.6690051
# 61                                   Harbourfront East  43.6408157
# 62                                     Toronto Islands  43.6408157
# 63                                       Union Station  43.6408157
# 64                                     Little Portugal  43.6479267
# 65                                             Trinity  43.6479267
# 72                                   The Danforth West  43.6795571
# 73                                           Riverdale  43.6795571
# 74                                     Design Exchange  43.6471768
# 75                             Toronto Dominion Centre  43.6471768
# 76                                            Brockton  43.6368472
# 77                                    Exhibition Place  43.6368472
# 78                                    Parkdale Village  43.6368472
# 85                                    The Beaches West  43.6689985
# 86                                        India Bazaar  43.6689985
# 87                                      Commerce Court  43.6481985
# 88                                      Victoria Hotel  43.6481985
# 99                                     Studio District  43.6595255
# 112                                      Lawrence Park  43.7280205
# 113                                           Roselawn  43.7116948
# 121                                   Davisville North  43.7127511
# 122                                  Forest Hill North  43.6969476
# 123                                   Forest Hill West  43.6969476
# 124                                          High Park  43.6616083
# 125                                 The Junction South  43.6616083
# 130                                 North Toronto West  43.7153834
# 131                                          The Annex  43.6727097
# 132                                      North Midtown  43.6727097
# 133                                          Yorkville  43.6727097
# 134                                           Parkdale  43.6489597
# 135                                       Roncesvalles  43.6489597
# 142                                         Davisville  43.7043244
# 143                                            Harbord  43.6626956
# 144                              University of Toronto  43.6626956
# 145                                          Runnymede  43.6515706
# 146                                            Swansea  43.6515706
# 150                                         Moore Park  43.6895743
# 151                                    Summerhill East  43.6895743
# 152                                          Chinatown  43.6532057
# 153                                        Grange Park  43.6532057
# 154                                  Kensington Market  43.6532057
# 159                                          Deer Park  43.6864123
# 160                                     Forest Hill SE  43.6864123
# 161                                          Rathnelly  43.6864123
# 162                                         South Hill  43.6864123
# 163                                    Summerhill West  43.6864123
# 164                                           CN Tower  43.6289467
# 165                                      Bathurst Quay  43.6289467
# 166                                     Island airport  43.6289467
# 167                                  Harbourfront West  43.6289467
# 168                                   King and Spadina  43.6289467
# 169                                      Railway Lands  43.6289467
# 170                                      South Niagara  43.6289467
# 183                                           Rosedale  43.6795626
# 184                    Stn A PO Boxes 25 The Esplanade  43.6464352
# 189                                        Cabbagetown   43.667967
# 190                                     St. James Town   43.667967
# 191                               First Canadian Place  43.6484292
# 192                                   Underground city  43.6484292
# 196                               Church and Wellesley  43.6658599
# 197  Business Reply Mail Processing Centre 969 Eastern  43.6627439
#
#        Longitude
# 2    -79.3606359
# 3    -79.3606359
# 13   -79.3789371
# 14   -79.3789371
# 27   -79.3754179
# 36   -79.2930312
# 37   -79.3733064
# 41   -79.3873826
# 42   -79.4225637
# 49   -79.3845675
# 50   -79.3845675
# 51   -79.3845675
# 52   -79.4422593
# 53   -79.4422593
# 61   -79.3817523
# 62   -79.3817523
# 63   -79.3817523
# 64   -79.4197497
# 65   -79.4197497
# 72    -79.352188
# 73    -79.352188
# 74   -79.3815764
# 75   -79.3815764
# 76   -79.4281914
# 77   -79.4281914
# 78   -79.4281914
# 85   -79.3155716
# 86   -79.3155716
# 87   -79.3798169
# 88   -79.3798169
# 99    -79.340923
# 112  -79.3887901
# 113  -79.4169356
# 121  -79.3901975
# 122  -79.4113072
# 123  -79.4113072
# 124  -79.4647633
# 125  -79.4647633
# 130  -79.4056784
# 131  -79.4056784
# 132  -79.4056784
# 133  -79.4056784
# 134   -79.456325
# 135   -79.456325
# 142  -79.3887901
# 143  -79.4000493
# 144  -79.4000493
# 145  -79.4844499
# 146  -79.4844499
# 150  -79.3831599
# 151  -79.3831599
# 152  -79.4000493
# 153  -79.4000493
# 154  -79.4000493
# 159  -79.4000493
# 160  -79.4000493
# 161  -79.4000493
# 162  -79.4000493
# 163  -79.4000493
# 164  -79.3944199
# 165  -79.3944199
# 166  -79.3944199
# 167  -79.3944199
# 168  -79.3944199
# 169  -79.3944199
# 170  -79.3944199
# 183  -79.3775294
# 184   -79.374846
# 189  -79.3676753
# 190  -79.3676753
# 191  -79.3822802
# 192  -79.3822802
# 196  -79.3831599
# 197   -79.321558

# %% [markdown]
# #### Creat Map with Toronto Neighborhoods

# %%
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="ca_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Toronto are 43.653963, -79.387207.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

toronto_data[["Latitude", "Longitude"]] = toronto_data[["Latitude", "Longitude"]].apply(pd.to_numeric)

# add markers to map
for lat, lng, label in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Call Foursquare to return venues

# %%
CLIENT_ID = '3Y43KRY30SIR454E01CPDGENENG5W24N20ZGBW3CKZTYG1A3' # your Foursquare ID
CLIENT_SECRET = 'QFFXGQLHJY1RXPDJEGRGLSHXI5Y1KQNPX3I22NO5S2TEJPTC' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude',
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )
# Out:
# Harbourfront
# Regent Park
# Ryerson
# Garden District
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Adelaide
# King
# Richmond
# Dovercourt Village
# Dufferin
# Harbourfront East
# Toronto Islands
# Union Station
# Little Portugal
# Trinity
# The Danforth West
# Riverdale
# Design Exchange
# Toronto Dominion Centre
# Brockton
# Exhibition Place
# Parkdale Village
# The Beaches West
# India Bazaar
# Commerce Court
# Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North
# Forest Hill West
# High Park
# The Junction South
# North Toronto West
# The Annex
# North Midtown
# Yorkville
# Parkdale
# Roncesvalles
# Davisville
# Harbord
# University of Toronto
# Runnymede
# Swansea
# Moore Park
# Summerhill East
# Chinatown
# Grange Park
# Kensington Market
# Deer Park
# Forest Hill SE
# Rathnelly
# South Hill
# Summerhill West
# CN Tower
# Bathurst Quay
# Island airport
# Harbourfront West
# King and Spadina
# Railway Lands
# South Niagara
# Rosedale
# Stn A PO Boxes 25 The Esplanade
# Cabbagetown
# St. James Town
# First Canadian Place
# Underground city
# Church and Wellesley
# Business Reply Mail Processing Centre 969 Eastern

# %% [markdown]
# #### Clean venues data and order by most common venues

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                           Adelaide           Coffee Shop
# 1                                      Bathurst Quay        Airport Lounge
# 2                                        Berczy Park           Coffee Shop
# 3                                           Brockton           Coffee Shop
# 4  Business Reply Mail Processing Centre 969 Eastern    Light Rail Station
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0            Steakhouse                  Café       Thai Restaurant
# 1      Airport Terminal       Airport Service                 Plane
# 2          Cocktail Bar                   Pub           Cheese Shop
# 3        Breakfast Spot                  Café           Yoga Studio
# 4           Yoga Studio                Garden        Farmers Market
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                   Bar      Sushi Restaurant   American Restaurant
# 1      Sculpture Garden              Boutique         Boat or Ferry
# 2            Steakhouse    Seafood Restaurant        Farmers Market
# 3         Burrito Place            Restaurant  Caribbean Restaurant
# 4                   Spa  Fast Food Restaurant               Brewery
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                 Hotel            Restaurant                    Gym
# 1       Harbor / Marina          Airport Gate                Airport
# 2            Restaurant                  Café                 Bakery
# 3          Climbing Gym             Pet Store                    Bar
# 4         Burrito Place            Restaurant          Auto Workshop

# %% [markdown]
# #### Cluster Toronto neighborhoods based on most common venues and display map

# %%
# set number of clusters
kclusters = 4

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head()
# Out:
#    PostalCode           Borough     Neighborhood   Latitude  Longitude  \
# 2         M5A  Downtown Toronto     Harbourfront  43.654260 -79.360636
# 3         M5A  Downtown Toronto      Regent Park  43.654260 -79.360636
# 13        M5B  Downtown Toronto          Ryerson  43.657162 -79.378937
# 14        M5B  Downtown Toronto  Garden District  43.657162 -79.378937
# 27        M5C  Downtown Toronto   St. James Town  43.651494 -79.375418
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 2                1           Coffee Shop                  Park
# 3                1           Coffee Shop                  Park
# 13               1           Coffee Shop        Clothing Store
# 14               1           Coffee Shop        Clothing Store
# 27               1           Coffee Shop            Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 2                   Café                   Pub                     Bakery
# 3                   Café                   Pub                     Bakery
# 13                  Café        Cosmetics Shop  Middle Eastern Restaurant
# 14                  Café        Cosmetics Shop  Middle Eastern Restaurant
# 27                  Café                Bakery                      Hotel
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 2         Breakfast Spot    Mexican Restaurant               Theater
# 3         Breakfast Spot    Mexican Restaurant               Theater
# 13            Restaurant                 Diner      Ramen Restaurant
# 14            Restaurant                 Diner      Ramen Restaurant
# 27    Italian Restaurant        Breakfast Spot             Gastropub
#
#    9th Most Common Venue 10th Most Common Venue
# 2         Ice Cream Shop         Chocolate Shop
# 3         Ice Cream Shop         Chocolate Shop
# 13           Pizza Place        Bubble Tea Shop
# 14           Pizza Place        Bubble Tea Shop
# 27                  Park                  Diner

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Display 4 clusters (0 - Trails and Parks; 1 - Coffee shops and snack bars; 2 - Top restaurants and gyms (central Toronto); 3 - Airport services)

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 164  Downtown Toronto               0        Airport Lounge
# 165  Downtown Toronto               0        Airport Lounge
# 166  Downtown Toronto               0        Airport Lounge
# 167  Downtown Toronto               0        Airport Lounge
# 168  Downtown Toronto               0        Airport Lounge
# 169  Downtown Toronto               0        Airport Lounge
# 170  Downtown Toronto               0        Airport Lounge
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 164      Airport Terminal       Airport Service                 Plane
# 165      Airport Terminal       Airport Service                 Plane
# 166      Airport Terminal       Airport Service                 Plane
# 167      Airport Terminal       Airport Service                 Plane
# 168      Airport Terminal       Airport Service                 Plane
# 169      Airport Terminal       Airport Service                 Plane
# 170      Airport Terminal       Airport Service                 Plane
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 164      Sculpture Garden              Boutique         Boat or Ferry
# 165      Sculpture Garden              Boutique         Boat or Ferry
# 166      Sculpture Garden              Boutique         Boat or Ferry
# 167      Sculpture Garden              Boutique         Boat or Ferry
# 168      Sculpture Garden              Boutique         Boat or Ferry
# 169      Sculpture Garden              Boutique         Boat or Ferry
# 170      Sculpture Garden              Boutique         Boat or Ferry
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 164       Harbor / Marina          Airport Gate                Airport
# 165       Harbor / Marina          Airport Gate                Airport
# 166       Harbor / Marina          Airport Gate                Airport
# 167       Harbor / Marina          Airport Gate                Airport
# 168       Harbor / Marina          Airport Gate                Airport
# 169       Harbor / Marina          Airport Gate                Airport
# 170       Harbor / Marina          Airport Gate                Airport

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 2    Downtown Toronto               1           Coffee Shop
# 3    Downtown Toronto               1           Coffee Shop
# 13   Downtown Toronto               1           Coffee Shop
# 14   Downtown Toronto               1           Coffee Shop
# 27   Downtown Toronto               1           Coffee Shop
# 36       East Toronto               1     Health Food Store
# 37   Downtown Toronto               1           Coffee Shop
# 41   Downtown Toronto               1           Coffee Shop
# 42   Downtown Toronto               1         Grocery Store
# 49   Downtown Toronto               1           Coffee Shop
# 50   Downtown Toronto               1           Coffee Shop
# 51   Downtown Toronto               1           Coffee Shop
# 52       West Toronto               1              Pharmacy
# 53       West Toronto               1              Pharmacy
# 61   Downtown Toronto               1           Coffee Shop
# 62   Downtown Toronto               1           Coffee Shop
# 63   Downtown Toronto               1           Coffee Shop
# 64       West Toronto               1                   Bar
# 65       West Toronto               1                   Bar
# 72       East Toronto               1      Greek Restaurant
# 73       East Toronto               1      Greek Restaurant
# 74   Downtown Toronto               1           Coffee Shop
# 75   Downtown Toronto               1           Coffee Shop
# 76       West Toronto               1           Coffee Shop
# 77       West Toronto               1           Coffee Shop
# 78       West Toronto               1           Coffee Shop
# 85       East Toronto               1                  Park
# 86       East Toronto               1                  Park
# 87   Downtown Toronto               1           Coffee Shop
# 88   Downtown Toronto               1           Coffee Shop
# 99       East Toronto               1                  Café
# 121   Central Toronto               1  Gym / Fitness Center
# 124      West Toronto               1                   Bar
# 125      West Toronto               1                   Bar
# 130   Central Toronto               1   Sporting Goods Shop
# 131   Central Toronto               1                  Café
# 132   Central Toronto               1                  Café
# 133   Central Toronto               1                  Café
# 134      West Toronto               1        Breakfast Spot
# 135      West Toronto               1        Breakfast Spot
# 142   Central Toronto               1        Sandwich Place
# 143  Downtown Toronto               1                  Café
# 144  Downtown Toronto               1                  Café
# 145      West Toronto               1           Coffee Shop
# 146      West Toronto               1           Coffee Shop
# 150   Central Toronto               1            Restaurant
# 151   Central Toronto               1            Restaurant
# 152  Downtown Toronto               1                  Café
# 153  Downtown Toronto               1                  Café
# 154  Downtown Toronto               1                  Café
# 159   Central Toronto               1           Coffee Shop
# 160   Central Toronto               1           Coffee Shop
# 161   Central Toronto               1           Coffee Shop
# 162   Central Toronto               1           Coffee Shop
# 163   Central Toronto               1           Coffee Shop
# 184  Downtown Toronto               1           Coffee Shop
# 189  Downtown Toronto               1           Coffee Shop
# 190  Downtown Toronto               1           Coffee Shop
# 191  Downtown Toronto               1           Coffee Shop
# 192  Downtown Toronto               1           Coffee Shop
# 196  Downtown Toronto               1           Coffee Shop
# 197      East Toronto               1    Light Rail Station
#
#     2nd Most Common Venue          3rd Most Common Venue  \
# 2                    Park                           Café
# 3                    Park                           Café
# 13         Clothing Store                           Café
# 14         Clothing Store                           Café
# 27             Restaurant                           Café
# 36            Coffee Shop                            Pub
# 37           Cocktail Bar                            Pub
# 41     Italian Restaurant                            Bar
# 42                   Café                           Park
# 49             Steakhouse                           Café
# 50             Steakhouse                           Café
# 51             Steakhouse                           Café
# 52            Supermarket                 Discount Store
# 53            Supermarket                 Discount Store
# 61               Aquarium                          Hotel
# 62               Aquarium                          Hotel
# 63               Aquarium                          Hotel
# 64            Coffee Shop               Asian Restaurant
# 65            Coffee Shop               Asian Restaurant
# 72            Coffee Shop                 Ice Cream Shop
# 73            Coffee Shop                 Ice Cream Shop
# 74                   Café                          Hotel
# 75                   Café                          Hotel
# 76         Breakfast Spot                           Café
# 77         Breakfast Spot                           Café
# 78         Breakfast Spot                           Café
# 85         Sandwich Place                      Pet Store
# 86         Sandwich Place                      Pet Store
# 87                   Café                          Hotel
# 88                   Café                          Hotel
# 99            Coffee Shop             Italian Restaurant
# 121                 Hotel                 Clothing Store
# 124    Mexican Restaurant                           Café
# 125    Mexican Restaurant                           Café
# 130        Clothing Store                    Coffee Shop
# 131           Coffee Shop                 Sandwich Place
# 132           Coffee Shop                 Sandwich Place
# 133           Coffee Shop                 Sandwich Place
# 134             Gift Shop             Italian Restaurant
# 135             Gift Shop             Italian Restaurant
# 142          Dessert Shop                    Pizza Place
# 143   Japanese Restaurant                         Bakery
# 144   Japanese Restaurant                         Bakery
# 145           Pizza Place                           Café
# 146           Pizza Place                           Café
# 150                   Gym                     Playground
# 151                   Gym                     Playground
# 152                   Bar  Vegetarian / Vegan Restaurant
# 153                   Bar  Vegetarian / Vegan Restaurant
# 154                   Bar  Vegetarian / Vegan Restaurant
# 159                   Pub            Fried Chicken Joint
# 160                   Pub            Fried Chicken Joint
# 161                   Pub            Fried Chicken Joint
# 162                   Pub            Fried Chicken Joint
# 163                   Pub            Fried Chicken Joint
# 184            Restaurant                           Café
# 189            Restaurant                         Bakery
# 190            Restaurant                           Café
# 191                  Café                          Hotel
# 192                  Café                          Hotel
# 196   Japanese Restaurant               Sushi Restaurant
# 197           Yoga Studio                         Garden
#
#      4th Most Common Venue        5th Most Common Venue  \
# 2                      Pub                       Bakery
# 3                      Pub                       Bakery
# 13          Cosmetics Shop    Middle Eastern Restaurant
# 14          Cosmetics Shop    Middle Eastern Restaurant
# 27                  Bakery                        Hotel
# 36           Women's Store          Dumpling Restaurant
# 37             Cheese Shop                   Steakhouse
# 41         Bubble Tea Shop                 Burger Joint
# 42               Nightclub                        Diner
# 49         Thai Restaurant                          Bar
# 50         Thai Restaurant                          Bar
# 51         Thai Restaurant                          Bar
# 52                  Bakery         Fast Food Restaurant
# 53                  Bakery         Fast Food Restaurant
# 61                    Café           Italian Restaurant
# 62                    Café           Italian Restaurant
# 63                    Café           Italian Restaurant
# 64                  Bakery                  Pizza Place
# 65                  Bakery                  Pizza Place
# 72      Italian Restaurant                  Yoga Studio
# 73      Italian Restaurant                  Yoga Studio
# 74     American Restaurant                   Restaurant
# 75     American Restaurant                   Restaurant
# 76             Yoga Studio                Burrito Place
# 77             Yoga Studio                Burrito Place
# 78             Yoga Studio                Burrito Place
# 85                 Brewery                 Burger Joint
# 86                 Brewery                 Burger Joint
# 87     American Restaurant                   Restaurant
# 88     American Restaurant                   Restaurant
# 99     American Restaurant                    Gastropub
# 121             Restaurant               Sandwich Place
# 124    Fried Chicken Joint                 Antique Shop
# 125    Fried Chicken Joint                 Antique Shop
# 130            Yoga Studio               Sandwich Place
# 131            Pizza Place            Indian Restaurant
# 132            Pizza Place            Indian Restaurant
# 133            Pizza Place            Indian Restaurant
# 134           Dessert Shop  Eastern European Restaurant
# 135           Dessert Shop  Eastern European Restaurant
# 142            Coffee Shop           Italian Restaurant
# 143                    Bar                    Bookstore
# 144                    Bar                    Bookstore
# 145       Sushi Restaurant           Italian Restaurant
# 146       Sushi Restaurant           Italian Restaurant
# 150           Tennis Court             Doner Restaurant
# 151           Tennis Court             Doner Restaurant
# 152  Vietnamese Restaurant                       Bakery
# 153  Vietnamese Restaurant                       Bakery
# 154  Vietnamese Restaurant                       Bakery
# 159       Sushi Restaurant                   Bagel Shop
# 160       Sushi Restaurant                   Bagel Shop
# 161       Sushi Restaurant                   Bagel Shop
# 162       Sushi Restaurant                   Bagel Shop
# 163       Sushi Restaurant                   Bagel Shop
# 184                  Hotel         Fast Food Restaurant
# 189            Pizza Place           Italian Restaurant
# 190                 Bakery                        Hotel
# 191             Steakhouse                    Gastropub
# 192             Steakhouse                    Gastropub
# 196                Gay Bar                 Burger Joint
# 197         Farmers Market                          Spa
#
#          6th Most Common Venue      7th Most Common Venue  \
# 2               Breakfast Spot         Mexican Restaurant
# 3               Breakfast Spot         Mexican Restaurant
# 13                  Restaurant                      Diner
# 14                  Restaurant                      Diner
# 27          Italian Restaurant             Breakfast Spot
# 36                       Diner             Discount Store
# 37          Seafood Restaurant             Farmers Market
# 41          Chinese Restaurant             Ice Cream Shop
# 42                  Baby Store         Athletics & Sports
# 49            Sushi Restaurant        American Restaurant
# 50            Sushi Restaurant        American Restaurant
# 51            Sushi Restaurant        American Restaurant
# 52                Liquor Store  Middle Eastern Restaurant
# 53                Liquor Store  Middle Eastern Restaurant
# 61                 Pizza Place                    Brewery
# 62                 Pizza Place                    Brewery
# 63                 Pizza Place                    Brewery
# 64                 Men's Store      Vietnamese Restaurant
# 65                 Men's Store      Vietnamese Restaurant
# 72                         Spa                  Bookstore
# 73                         Spa                  Bookstore
# 74                   Gastropub         Italian Restaurant
# 75                   Gastropub         Italian Restaurant
# 76                  Restaurant       Caribbean Restaurant
# 77                  Restaurant       Caribbean Restaurant
# 78                  Restaurant       Caribbean Restaurant
# 85               Burrito Place                        Pub
# 86               Burrito Place                        Pub
# 87                   Gastropub              Deli / Bodega
# 88                   Gastropub              Deli / Bodega
# 99                      Bakery             Clothing Store
# 121               Burger Joint             Breakfast Spot
# 124  Cajun / Creole Restaurant                      Diner
# 125  Cajun / Creole Restaurant                      Diner
# 130         Salon / Barbershop        Rental Car Location
# 131                  BBQ Joint          Jewish Restaurant
# 132                  BBQ Joint          Jewish Restaurant
# 133                  BBQ Joint          Jewish Restaurant
# 134                        Bar                       Bank
# 135                        Bar                       Bank
# 142                       Café           Sushi Restaurant
# 143                 Restaurant                        Gym
# 144                 Restaurant                        Gym
# 145                   Tea Room                        Pub
# 146                   Tea Room                        Pub
# 150         Dim Sum Restaurant                      Diner
# 151         Dim Sum Restaurant                      Diner
# 152                Coffee Shop         Chinese Restaurant
# 153                Coffee Shop         Chinese Restaurant
# 154                Coffee Shop         Chinese Restaurant
# 159                 Sports Bar        American Restaurant
# 160                 Sports Bar        American Restaurant
# 161                 Sports Bar        American Restaurant
# 162                 Sports Bar        American Restaurant
# 163                 Sports Bar        American Restaurant
# 184         Seafood Restaurant                        Pub
# 189                       Café                        Pub
# 190         Italian Restaurant             Breakfast Spot
# 191         Seafood Restaurant                        Bar
# 192         Seafood Restaurant                        Bar
# 196                 Restaurant            Bubble Tea Shop
# 197       Fast Food Restaurant                    Brewery
#
#        8th Most Common Venue     9th Most Common Venue  \
# 2                    Theater            Ice Cream Shop
# 3                    Theater            Ice Cream Shop
# 13          Ramen Restaurant               Pizza Place
# 14          Ramen Restaurant               Pizza Place
# 27                 Gastropub                      Park
# 36                   Dog Run          Doner Restaurant
# 37                Restaurant                      Café
# 41           Thai Restaurant                      Café
# 42        Italian Restaurant                Restaurant
# 49                     Hotel                Restaurant
# 50                     Hotel                Restaurant
# 51                     Hotel                Restaurant
# 52               Music Venue                      Park
# 53               Music Venue                      Park
# 61                    Bakery            Scenic Lookout
# 62                    Bakery            Scenic Lookout
# 63                    Bakery            Scenic Lookout
# 64   New American Restaurant              Cocktail Bar
# 65   New American Restaurant              Cocktail Bar
# 72                   Brewery           Bubble Tea Shop
# 73                   Brewery           Bubble Tea Shop
# 74        Seafood Restaurant             Deli / Bodega
# 75        Seafood Restaurant             Deli / Bodega
# 76              Climbing Gym                 Pet Store
# 77              Climbing Gym                 Pet Store
# 78              Climbing Gym                 Pet Store
# 85               Pizza Place             Movie Theater
# 86               Pizza Place             Movie Theater
# 87        Italian Restaurant                    Bakery
# 88        Italian Restaurant                    Bakery
# 99                 Bookstore          Stationery Store
# 121        Food & Drink Shop          Asian Restaurant
# 124       Italian Restaurant       Arts & Crafts Store
# 125       Italian Restaurant       Arts & Crafts Store
# 130       Chinese Restaurant                      Park
# 131                      Pub               Cheese Shop
# 132                      Pub               Cheese Shop
# 133                      Pub               Cheese Shop
# 134             Burger Joint                   Dog Run
# 135             Burger Joint                   Dog Run
# 142             Gourmet Shop        Chinese Restaurant
# 143                 Beer Bar                Beer Store
# 144                 Beer Bar                Beer Store
# 145                     Food              Dessert Shop
# 146                     Food              Dessert Shop
# 150           Discount Store                   Dog Run
# 151           Discount Store                   Dog Run
# 152       Mexican Restaurant               Gaming Cafe
# 153       Mexican Restaurant               Gaming Cafe
# 154       Mexican Restaurant               Gaming Cafe
# 159           Medical Center               Supermarket
# 160           Medical Center               Supermarket
# 161           Medical Center               Supermarket
# 162           Medical Center               Supermarket
# 163           Medical Center               Supermarket
# 184             Cocktail Bar               Cheese Shop
# 189                     Park        Chinese Restaurant
# 190                Gastropub                      Park
# 191                   Bakery                Restaurant
# 192                   Bakery                Restaurant
# 196                     Café  Mediterranean Restaurant
# 197            Burrito Place                Restaurant
#
#       10th Most Common Venue
# 2             Chocolate Shop
# 3             Chocolate Shop
# 13           Bubble Tea Shop
# 14           Bubble Tea Shop
# 27                     Diner
# 36                Donut Shop
# 37                    Bakery
# 41               Salad Place
# 42         Convenience Store
# 49                       Gym
# 50                       Gym
# 51                       Gym
# 52               Pizza Place
# 53               Pizza Place
# 61       Fried Chicken Joint
# 62       Fried Chicken Joint
# 63       Fried Chicken Joint
# 64                Restaurant
# 65                Restaurant
# 72                Restaurant
# 73                Restaurant
# 74               Pizza Place
# 75               Pizza Place
# 76                       Bar
# 77                       Bar
# 78                       Bar
# 85          Sushi Restaurant
# 86          Sushi Restaurant
# 87                Steakhouse
# 88                Steakhouse
# 99   Comfort Food Restaurant
# 121                     Park
# 124   Furniture / Home Store
# 125   Furniture / Home Store
# 130             Dessert Shop
# 131             Burger Joint
# 132             Burger Joint
# 133             Burger Joint
# 134               Restaurant
# 135               Restaurant
# 142                  Brewery
# 143           Sandwich Place
# 144           Sandwich Place
# 145        Fish & Chips Shop
# 146        Fish & Chips Shop
# 150      Dumpling Restaurant
# 151      Dumpling Restaurant
# 152      Dumpling Restaurant
# 153      Dumpling Restaurant
# 154      Dumpling Restaurant
# 159        Convenience Store
# 160        Convenience Store
# 161        Convenience Store
# 162        Convenience Store
# 163        Convenience Store
# 184                 Beer Bar
# 189           Farmers Market
# 190                    Diner
# 191            Deli / Bodega
# 192            Deli / Bodega
# 196              Yoga Studio
# 197            Auto Workshop

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 113  Central Toronto               2          Home Service
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 113                Garden         Women's Store    Dim Sum Restaurant
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 113        Farmers Market    Falafel Restaurant           Event Space
#
#     8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 113  Ethiopian Restaurant     Electronics Store  Eastern European Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 112   Central Toronto               3              Bus Line
# 122   Central Toronto               3                 Trail
# 123   Central Toronto               3                 Trail
# 183  Downtown Toronto               3                  Park
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 112                  Park                  Lake           Swim School
# 122                  Park         Jewelry Store      Sushi Restaurant
# 123                  Park         Jewelry Store      Sushi Restaurant
# 183                 Trail            Playground            Donut Shop
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 112         Women's Store    Falafel Restaurant           Event Space
# 122            Donut Shop                 Diner        Discount Store
# 123            Donut Shop                 Diner        Discount Store
# 183    Dim Sum Restaurant                 Diner        Discount Store
#
#     8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 112  Ethiopian Restaurant     Electronics Store  Eastern European Restaurant
# 122               Dog Run      Doner Restaurant                Women's Store
# 123               Dog Run      Doner Restaurant                Women's Store
# 183               Dog Run      Doner Restaurant                Women's Store
