# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

#!conda install -c anaconda beautifulsoup4

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Import Toronto Postal Codes data and copy to dataframe

# %%
from bs4 import BeautifulSoup
import requests
r  = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
data = r.text
soup = BeautifulSoup(data)

table = soup.find( "table", {"class":"wikitable sortable"} )

rows=list()
for row in table.findAll("tr"):
   rows.append(row)

l = []
for tr in rows:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    l.append(row)
toronto_df = pd.DataFrame(l, columns=['PostalCode','Borough','Neighborhood'])

# %% [markdown]
# #### Clean data

# %%
toronto_df = toronto_df.replace(to_replace='none', value=np.nan).dropna()
toronto_df = toronto_df[toronto_df['Borough'] != 'Not assigned']
toronto_df.reset_index(drop=True)
toronto_df['Neighborhood'] = toronto_df['Neighborhood'].str[:-1]

# %%
toronto_df.groupby('PostalCode').agg(dict(Borough = 'min', Neighborhood = lambda y: '%s'%', '.join(y)))
                             #   .agg(dict(A = 'sum', B = 'sum', C = lambda x: '{%s}'%', '.join(x)))
toronto_df.loc[toronto_df['Neighborhood'].str.contains("Not assign"), 'Neighborhood'] = toronto_df['Borough']

# %%
toronto_df[toronto_df['Borough'] == 'Queen\'s Park']
toronto_df.shape
# Out:
# (211, 3)

# %% [markdown]
# #### Get geolocation data and merge with PostalCodes data

# %%
pc  = requests.get("http://cocl.us/Geospatial_data")
data_pc = pc.text
soup_pc = BeautifulSoup(data_pc)
postalCodes = soup_pc.find('p').getText()

# %%
postalCodes.splitlines()
postalCodes_df = pd.DataFrame(postalCodes.splitlines())
postalCodes_df = pd.DataFrame(postalCodes_df[0].str.split(',').tolist(),
                                   columns = ['PostalCode','Latitude','Longitude'])
postalCodes_df = postalCodes_df[postalCodes_df['PostalCode'] != 'Postal Code']
toronto_data = pd.merge(toronto_df, postalCodes_df, left_on='PostalCode', right_on='PostalCode', how='left')
toronto_data = toronto_data[toronto_data['Borough'].str.contains('Toronto')]
toronto_data
# Out:
#     PostalCode           Borough  \
# 2          M5A  Downtown Toronto
# 3          M5A  Downtown Toronto
# 13         M5B  Downtown Toronto
# 14         M5B  Downtown Toronto
# 27         M5C  Downtown Toronto
# 36         M4E      East Toronto
# 37         M5E  Downtown Toronto
# 41         M5G  Downtown Toronto
# 42         M6G  Downtown Toronto
# 49         M5H  Downtown Toronto
# 50         M5H  Downtown Toronto
# 51         M5H  Downtown Toronto
# 52         M6H      West Toronto
# 53         M6H      West Toronto
# 61         M5J  Downtown Toronto
# 62         M5J  Downtown Toronto
# 63         M5J  Downtown Toronto
# 64         M6J      West Toronto
# 65         M6J      West Toronto
# 72         M4K      East Toronto
# 73         M4K      East Toronto
# 74         M5K  Downtown Toronto
# 75         M5K  Downtown Toronto
# 76         M6K      West Toronto
# 77         M6K      West Toronto
# 78         M6K      West Toronto
# 85         M4L      East Toronto
# 86         M4L      East Toronto
# 87         M5L  Downtown Toronto
# 88         M5L  Downtown Toronto
# 99         M4M      East Toronto
# 112        M4N   Central Toronto
# 113        M5N   Central Toronto
# 121        M4P   Central Toronto
# 122        M5P   Central Toronto
# 123        M5P   Central Toronto
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Adelaide
# King
# Richmond
# Dovercourt Village
# Dufferin
# Harbourfront East
# Toronto Islands
# Union Station
# Little Portugal
# Trinity
# The Danforth West
# Riverdale
# Design Exchange
# Toronto Dominion Centre
# Brockton
# Exhibition Place
# Parkdale Village
# The Beaches West
# India Bazaar
# Commerce Court
# Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North
# Forest Hill West
# High Park
# The Junction South
# North Toronto West
# The Annex
# North Midtown
# Yorkville
# Parkdale
# Roncesvalles
# Davisville
# Harbord
# University of Toronto
# Runnymede
# Swansea
# Moore Park
# Summerhill East
# Chinatown
# Grange Park
# Kensington Market
# Deer Park
# Forest Hill SE
# Rathnelly
# South Hill
# Summerhill West
# CN Tower
# Bathurst Quay
# Island airport
# Harbourfront West
# King and Spadina
# Railway Lands
# South Niagara
# Rosedale
# Stn A PO Boxes 25 The Esplanade
# Cabbagetown
# St. James Town
# First Canadian Place
# Underground city
# Church and Wellesley
# Business Reply Mail Processing Centre 969 Eastern

# %% [markdown]
# #### Clean venues data and order by most common venues

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                           Adelaide           Coffee Shop
# 1                                      Bathurst Quay        Airport Lounge
# 2                                        Berczy Park           Coffee Shop
# 3                                           Brockton           Coffee Shop
# 4  Business Reply Mail Processing Centre 969 Eastern    Light Rail Station
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0            Steakhouse                  Café       Thai Restaurant
# 1      Airport Terminal       Airport Service                 Plane
# 2          Cocktail Bar                   Pub           Cheese Shop
# 3        Breakfast Spot                  Café           Yoga Studio
# 4           Yoga Studio                Garden        Farmers Market
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                   Bar      Sushi Restaurant   American Restaurant
# 1      Sculpture Garden              Boutique         Boat or Ferry
# 2            Steakhouse    Seafood Restaurant        Farmers Market
# 3         Burrito Place            Restaurant  Caribbean Restaurant
# 4                   Spa  Fast Food Restaurant               Brewery
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                 Hotel            Restaurant                    Gym
# 1       Harbor / Marina          Airport Gate                Airport
# 2            Restaurant                  Café                 Bakery
# 3          Climbing Gym             Pet Store                    Bar
# 4         Burrito Place            Restaurant          Auto Workshop

# %% [markdown]
# #### Cluster Toronto neighborhoods based on most common venues and display map

# %%
# set number of clusters
kclusters = 4

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head()
# Out:
#    PostalCode           Borough     Neighborhood   Latitude  Longitude  \
# 2         M5A  Downtown Toronto     Harbourfront  43.654260 -79.360636
# 3         M5A  Downtown Toronto      Regent Park  43.654260 -79.360636
# 13        M5B  Downtown Toronto          Ryerson  43.657162 -79.378937
# 14        M5B  Downtown Toronto  Garden District  43.657162 -79.378937
# 27        M5C  Downtown Toronto   St. James Town  43.651494 -79.375418
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 2                1           Coffee Shop                  Park
# 3                1           Coffee Shop                  Park
# 13               1           Coffee Shop        Clothing Store
# 14               1           Coffee Shop        Clothing Store
# 27               1           Coffee Shop            Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 2                   Café                   Pub                     Bakery
# 3                   Café                   Pub                     Bakery
# 13                  Café        Cosmetics Shop  Middle Eastern Restaurant
# 14                  Café        Cosmetics Shop  Middle Eastern Restaurant
# 27                  Café                Bakery                      Hotel
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 2         Breakfast Spot    Mexican Restaurant               Theater
# 3         Breakfast Spot    Mexican Restaurant               Theater
# 13            Restaurant                 Diner      Ramen Restaurant
# 14            Restaurant                 Diner      Ramen Restaurant
# 27    Italian Restaurant        Breakfast Spot             Gastropub
#
#    9th Most Common Venue 10th Most Common Venue
# 2         Ice Cream Shop         Chocolate Shop
# 3         Ice Cream Shop         Chocolate Shop
# 13           Pizza Place        Bubble Tea Shop
# 14           Pizza Place        Bubble Tea Shop
# 27                  Park                  Diner

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Display 4 clusters (0 - Trails and Parks; 1 - Coffee shops and snack bars; 2 - Top restaurants and gyms (central Toronto); 3 - Airport services)

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 112   Central Toronto               0              Bus Line
# 122   Central Toronto               0                 Trail
# 123   Central Toronto               0                 Trail
# 183  Downtown Toronto               0                  Park
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 112                  Park                  Lake           Swim School
# 122                  Park         Jewelry Store      Sushi Restaurant
# 123                  Park         Jewelry Store      Sushi Restaurant
# 183                 Trail            Playground            Donut Shop
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 112         Women's Store    Falafel Restaurant           Event Space
# 122   Dumpling Restaurant        Discount Store               Dog Run
# 123   Dumpling Restaurant        Discount Store               Dog Run
# 183    Dim Sum Restaurant                 Diner        Discount Store
#
#     8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 112  Ethiopian Restaurant     Electronics Store  Eastern European Restaurant
# 122      Doner Restaurant            Donut Shop                Women's Store
# 123      Doner Restaurant            Donut Shop                Women's Store
# 183               Dog Run      Doner Restaurant                Women's Store

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 2    Downtown Toronto               1           Coffee Shop
# 3    Downtown Toronto               1           Coffee Shop
# 13   Downtown Toronto               1           Coffee Shop
# 14   Downtown Toronto               1           Coffee Shop
# 27   Downtown Toronto               1           Coffee Shop
# 36       East Toronto               1     Health Food Store
# 37   Downtown Toronto               1           Coffee Shop
# 41   Downtown Toronto               1           Coffee Shop
# 42   Downtown Toronto               1         Grocery Store
# 49   Downtown Toronto               1           Coffee Shop
# 50   Downtown Toronto               1           Coffee Shop
# 51   Downtown Toronto               1           Coffee Shop
# 52       West Toronto               1              Pharmacy
# 53       West Toronto               1              Pharmacy
# 61   Downtown Toronto               1           Coffee Shop
# 62   Downtown Toronto               1           Coffee Shop
# 63   Downtown Toronto               1           Coffee Shop
# 64       West Toronto               1                   Bar
# 65       West Toronto               1                   Bar
# 72       East Toronto               1      Greek Restaurant
# 73       East Toronto               1      Greek Restaurant
# 74   Downtown Toronto               1           Coffee Shop
# 75   Downtown Toronto               1           Coffee Shop
# 76       West Toronto               1        Breakfast Spot
# 77       West Toronto               1        Breakfast Spot
# 78       West Toronto               1        Breakfast Spot
# 85       East Toronto               1                  Park
# 86       East Toronto               1                  Park
# 87   Downtown Toronto               1           Coffee Shop
# 88   Downtown Toronto               1           Coffee Shop
# 99       East Toronto               1                  Café
# 121   Central Toronto               1        Sandwich Place
# 124      West Toronto               1                   Bar
# 125      West Toronto               1                   Bar
# 130   Central Toronto               1           Coffee Shop
# 131   Central Toronto               1        Sandwich Place
# 132   Central Toronto               1        Sandwich Place
# 133   Central Toronto               1        Sandwich Place
# 134      West Toronto               1        Breakfast Spot
# 135      West Toronto               1        Breakfast Spot
# 142   Central Toronto               1        Sandwich Place
# 143  Downtown Toronto               1                  Café
# 144  Downtown Toronto               1                  Café
# 145      West Toronto               1           Coffee Shop
# 146      West Toronto               1           Coffee Shop
# 152  Downtown Toronto               1                  Café
# 153  Downtown Toronto               1                  Café
# 154  Downtown Toronto               1                  Café
# 159   Central Toronto               1                   Pub
# 160   Central Toronto               1                   Pub
# 161   Central Toronto               1                   Pub
# 162   Central Toronto               1                   Pub
# 163   Central Toronto               1                   Pub
# 184  Downtown Toronto               1           Coffee Shop
# 189  Downtown Toronto               1           Coffee Shop
# 190  Downtown Toronto               1           Coffee Shop
# 191  Downtown Toronto               1           Coffee Shop
# 192  Downtown Toronto               1           Coffee Shop
# 196  Downtown Toronto               1           Coffee Shop
# 197      East Toronto               1    Light Rail Station
#
#     2nd Most Common Venue          3rd Most Common Venue  \
# 2                    Park                           Café
# 3                    Park                           Café
# 13         Clothing Store                           Café
# 14         Clothing Store                           Café
# 27             Restaurant                           Café
# 36            Coffee Shop                            Pub
# 37           Cocktail Bar                            Pub
# 41     Italian Restaurant                   Burger Joint
# 42                   Café                           Park
# 49                   Café                     Steakhouse
# 50                   Café                     Steakhouse
# 51                   Café                     Steakhouse
# 52            Supermarket                 Discount Store
# 53            Supermarket                 Discount Store
# 61               Aquarium                          Hotel
# 62               Aquarium                          Hotel
# 63               Aquarium                          Hotel
# 64            Coffee Shop               Asian Restaurant
# 65            Coffee Shop               Asian Restaurant
# 72            Coffee Shop                 Ice Cream Shop
# 73            Coffee Shop                 Ice Cream Shop
# 74                   Café                          Hotel
# 75                   Café                          Hotel
# 76                   Café                    Coffee Shop
# 77                   Café                    Coffee Shop
# 78                   Café                    Coffee Shop
# 85         Sandwich Place                      Pet Store
# 86         Sandwich Place                      Pet Store
# 87                   Café                          Hotel
# 88                   Café                          Hotel
# 99            Coffee Shop                      Gastropub
# 121  Gym / Fitness Center                            Gym
# 124    Mexican Restaurant                           Café
# 125    Mexican Restaurant                           Café
# 130        Clothing Store            Sporting Goods Shop
# 131           Coffee Shop                           Café
# 132           Coffee Shop                           Café
# 133           Coffee Shop                           Café
# 134             Gift Shop                      Bookstore
# 135             Gift Shop                      Bookstore
# 142          Dessert Shop                    Pizza Place
# 143   Japanese Restaurant                         Bakery
# 144   Japanese Restaurant                         Bakery
# 145                  Café                    Pizza Place
# 146                  Café                    Pizza Place
# 152                   Bar  Vegetarian / Vegan Restaurant
# 153                   Bar  Vegetarian / Vegan Restaurant
# 154                   Bar  Vegetarian / Vegan Restaurant
# 159           Coffee Shop                    Supermarket
# 160           Coffee Shop                    Supermarket
# 161           Coffee Shop                    Supermarket
# 162           Coffee Shop                    Supermarket
# 163           Coffee Shop                    Supermarket
# 184                  Café                     Restaurant
# 189            Restaurant                    Pizza Place
# 190            Restaurant                           Café
# 191                  Café                          Hotel
# 192                  Café                          Hotel
# 196   Japanese Restaurant               Sushi Restaurant
# 197           Yoga Studio                         Garden
#
#      4th Most Common Venue      5th Most Common Venue  \
# 2                      Pub                     Bakery
# 3                      Pub                     Bakery
# 13          Cosmetics Shop  Middle Eastern Restaurant
# 14          Cosmetics Shop  Middle Eastern Restaurant
# 27          Breakfast Spot                      Hotel
# 36           Women's Store        Dumpling Restaurant
# 37             Cheese Shop                 Steakhouse
# 41      Chinese Restaurant            Bubble Tea Shop
# 42               Nightclub                      Diner
# 49                     Bar            Thai Restaurant
# 50                     Bar            Thai Restaurant
# 51                     Bar            Thai Restaurant
# 52                  Bakery                       Park
# 53                  Bakery                       Park
# 61                    Café         Italian Restaurant
# 62                    Café         Italian Restaurant
# 63                    Café         Italian Restaurant
# 64                  Bakery      Vietnamese Restaurant
# 65                  Bakery      Vietnamese Restaurant
# 72      Italian Restaurant              Grocery Store
# 73      Italian Restaurant              Grocery Store
# 74     American Restaurant                 Restaurant
# 75     American Restaurant                 Restaurant
# 76             Yoga Studio               Climbing Gym
# 77             Yoga Studio               Climbing Gym
# 78             Yoga Studio               Climbing Gym
# 85                 Brewery               Burger Joint
# 86                 Brewery               Burger Joint
# 87              Restaurant        American Restaurant
# 88              Restaurant        American Restaurant
# 99                  Bakery         Italian Restaurant
# 121       Asian Restaurant                       Park
# 124    Fried Chicken Joint               Antique Shop
# 125    Fried Chicken Joint               Antique Shop
# 130           Dessert Shop             Sandwich Place
# 131            Pizza Place               Liquor Store
# 132            Pizza Place               Liquor Store
# 133            Pizza Place               Liquor Store
# 134                    Bar                 Restaurant
# 135                    Bar                 Restaurant
# 142            Coffee Shop                       Café
# 143                    Bar                  Bookstore
# 144                    Bar                  Bookstore
# 145       Sushi Restaurant         Italian Restaurant
# 146       Sushi Restaurant         Italian Restaurant
# 152            Coffee Shop      Vietnamese Restaurant
# 153            Coffee Shop      Vietnamese Restaurant
# 154            Coffee Shop      Vietnamese Restaurant
# 159  Vietnamese Restaurant         Light Rail Station
# 160  Vietnamese Restaurant         Light Rail Station
# 161  Vietnamese Restaurant         Light Rail Station
# 162  Vietnamese Restaurant         Light Rail Station
# 163  Vietnamese Restaurant         Light Rail Station
# 184           Cocktail Bar         Seafood Restaurant
# 189                 Bakery                       Café
# 190         Breakfast Spot                      Hotel
# 191             Steakhouse        American Restaurant
# 192             Steakhouse        American Restaurant
# 196                Gay Bar               Burger Joint
# 197             Smoke Shop                    Brewery
#
#          6th Most Common Venue    7th Most Common Venue 8th Most Common Venue  \
# 2               Breakfast Spot       Mexican Restaurant               Theater
# 3               Breakfast Spot       Mexican Restaurant               Theater
# 13                    Tea Room          Bubble Tea Shop           Pizza Place
# 14                    Tea Room          Bubble Tea Shop           Pizza Place
# 27          Italian Restaurant                   Bakery             Gastropub
# 36                       Diner           Discount Store               Dog Run
# 37          Seafood Restaurant           Farmers Market            Restaurant
# 41                         Bar                     Café       Thai Restaurant
# 42                  Baby Store       Athletics & Sports            Restaurant
# 49                  Restaurant         Sushi Restaurant   American Restaurant
# 50                  Restaurant         Sushi Restaurant   American Restaurant
# 51                  Restaurant         Sushi Restaurant   American Restaurant
# 52        Gym / Fitness Center              Pizza Place           Music Venue
# 53        Gym / Fitness Center              Pizza Place           Music Venue
# 61                      Bakery                  Brewery        Scenic Lookout
# 62                      Bakery                  Brewery        Scenic Lookout
# 63                      Bakery                  Brewery        Scenic Lookout
# 64                  Restaurant  New American Restaurant           Men's Store
# 65                  Restaurant  New American Restaurant           Men's Store
# 72                         Spa                Bookstore               Brewery
# 73                         Spa                Bookstore               Brewery
# 74          Italian Restaurant                Gastropub         Deli / Bodega
# 75          Italian Restaurant                Gastropub         Deli / Bodega
# 76               Burrito Place                  Stadium                   Bar
# 77               Burrito Place                  Stadium                   Bar
# 78               Burrito Place                  Stadium                   Bar
# 85               Burrito Place                      Pub           Pizza Place
# 86               Burrito Place                      Pub           Pizza Place
# 87          Seafood Restaurant                   Bakery            Steakhouse
# 88          Seafood Restaurant                   Bakery            Steakhouse
# 99         American Restaurant              Yoga Studio             Bookstore
# 121             Breakfast Spot           Clothing Store                 Hotel
# 124  Cajun / Creole Restaurant                    Diner    Italian Restaurant
# 125  Cajun / Creole Restaurant                    Diner    Italian Restaurant
# 130         Salon / Barbershop      Rental Car Location    Chinese Restaurant
# 131        American Restaurant             Burger Joint     Jewish Restaurant
# 132        American Restaurant             Burger Joint     Jewish Restaurant
# 133        American Restaurant             Burger Joint     Jewish Restaurant
# 134         Italian Restaurant            Movie Theater          Burger Joint
# 135         Italian Restaurant            Movie Theater          Burger Joint
# 142         Italian Restaurant         Sushi Restaurant                   Gym
# 143                 Restaurant                      Gym              Beer Bar
# 144                 Restaurant                      Gym              Beer Bar
# 145                   Tea Room                      Bar                  Food
# 146                   Tea Room                      Bar                  Food
# 152                     Bakery       Mexican Restaurant    Chinese Restaurant
# 153                     Bakery       Mexican Restaurant    Chinese Restaurant
# 154                     Bakery       Mexican Restaurant    Chinese Restaurant
# 159        Fried Chicken Joint              Pizza Place     Convenience Store
# 160        Fried Chicken Joint              Pizza Place     Convenience Store
# 161        Fried Chicken Joint              Pizza Place     Convenience Store
# 162        Fried Chicken Joint              Pizza Place     Convenience Store
# 163        Fried Chicken Joint              Pizza Place     Convenience Store
# 184                      Hotel                      Pub  Fast Food Restaurant
# 189                        Pub                     Park    Italian Restaurant
# 190         Italian Restaurant                   Bakery             Gastropub
# 191         Seafood Restaurant                Gastropub                   Bar
# 192         Seafood Restaurant                Gastropub                   Bar
# 196                 Restaurant              Yoga Studio           Men's Store
# 197             Farmers Market                      Spa  Fast Food Restaurant
#
#     9th Most Common Venue     10th Most Common Venue
# 2          Ice Cream Shop             Chocolate Shop
# 3          Ice Cream Shop             Chocolate Shop
# 13     Italian Restaurant                      Diner
# 14     Italian Restaurant                      Diner
# 27                   Park             Farmers Market
# 36       Doner Restaurant                 Donut Shop
# 37                   Café                     Bakery
# 41                    Spa           Sushi Restaurant
# 42     Italian Restaurant                Coffee Shop
# 49                  Hotel                     Bakery
# 50                  Hotel                     Bakery
# 51                  Hotel                     Bakery
# 52                   Pool  Middle Eastern Restaurant
# 53                   Pool  Middle Eastern Restaurant
# 61    Fried Chicken Joint                Pizza Place
# 62    Fried Chicken Joint                Pizza Place
# 63    Fried Chicken Joint                Pizza Place
# 64           Cocktail Bar                       Café
# 65           Cocktail Bar                       Café
# 72        Bubble Tea Shop                 Restaurant
# 73        Bubble Tea Shop                 Restaurant
# 74     Seafood Restaurant                        Bar
# 75     Seafood Restaurant                        Bar
# 76             Restaurant       Caribbean Restaurant
# 77             Restaurant       Caribbean Restaurant
# 78             Restaurant       Caribbean Restaurant
# 85          Movie Theater           Sushi Restaurant
# 86          Movie Theater           Sushi Restaurant
# 87     Italian Restaurant                        Gym
# 88     Italian Restaurant                        Gym
# 99                Brewery         Seafood Restaurant
# 121            Restaurant               Burger Joint
# 124   Arts & Crafts Store     Furniture / Home Store
# 125   Arts & Crafts Store     Furniture / Home Store
# 130                  Park                      Diner
# 131             BBQ Joint                        Pub
# 132             BBQ Joint                        Pub
# 133             BBQ Joint                        Pub
# 134          Dessert Shop                       Bank
# 135          Dessert Shop                       Bank
# 142   Fried Chicken Joint                    Brewery
# 143            Beer Store             Sandwich Place
# 144            Beer Store             Sandwich Place
# 145          Dessert Shop          Fish & Chips Shop
# 146          Dessert Shop          Fish & Chips Shop
# 152    Dim Sum Restaurant    Comfort Food Restaurant
# 153    Dim Sum Restaurant    Comfort Food Restaurant
# 154    Dim Sum Restaurant    Comfort Food Restaurant
# 159        Medical Center           Sushi Restaurant
# 160        Medical Center           Sushi Restaurant
# 161        Medical Center           Sushi Restaurant
# 162        Medical Center           Sushi Restaurant
# 163        Medical Center           Sushi Restaurant
# 184              Creperie                     Lounge
# 189            Playground             Breakfast Spot
# 190                  Park             Farmers Market
# 191                Bakery                 Restaurant
# 192                Bakery                 Restaurant
# 196                  Café            Bubble Tea Shop
# 197         Burrito Place                 Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 150  Central Toronto               2            Restaurant
# 151  Central Toronto               2            Restaurant
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 150                   Gym            Playground          Tennis Court
# 151                   Gym            Playground          Tennis Court
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 150      Doner Restaurant    Dim Sum Restaurant                 Diner
# 151      Doner Restaurant    Dim Sum Restaurant                 Diner
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 150        Discount Store               Dog Run    Dumpling Restaurant
# 151        Discount Store               Dog Run    Dumpling Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 164  Downtown Toronto               3        Airport Lounge
# 165  Downtown Toronto               3        Airport Lounge
# 166  Downtown Toronto               3        Airport Lounge
# 167  Downtown Toronto               3        Airport Lounge
# 168  Downtown Toronto               3        Airport Lounge
# 169  Downtown Toronto               3        Airport Lounge
# 170  Downtown Toronto               3        Airport Lounge
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 164       Airport Service      Airport Terminal              Boutique
# 165       Airport Service      Airport Terminal              Boutique
# 166       Airport Service      Airport Terminal              Boutique
# 167       Airport Service      Airport Terminal              Boutique
# 168       Airport Service      Airport Terminal              Boutique
# 169       Airport Service      Airport Terminal              Boutique
# 170       Airport Service      Airport Terminal              Boutique
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 164       Harbor / Marina         Boat or Ferry               Airport
# 165       Harbor / Marina         Boat or Ferry               Airport
# 166       Harbor / Marina         Boat or Ferry               Airport
# 167       Harbor / Marina         Boat or Ferry               Airport
# 168       Harbor / Marina         Boat or Ferry               Airport
# 169       Harbor / Marina         Boat or Ferry               Airport
# 170       Harbor / Marina         Boat or Ferry               Airport
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 164    Airport Food Court          Airport Gate                  Plane
# 165    Airport Food Court          Airport Gate                  Plane
# 166    Airport Food Court          Airport Gate                  Plane
# 167    Airport Food Court          Airport Gate                  Plane
# 168    Airport Food Court          Airport Gate                  Plane
# 169    Airport Food Court          Airport Gate                  Plane
# 170    Airport Food Court          Airport Gate                  Plane
